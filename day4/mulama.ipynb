# %%
import pandas as pd  ## Main package used for dataframes in Python

# %%
## Read in some data

# help(pd.read_csv)    ## Querry the function for reading csv files

url = 'https://drive.google.com/file/d/156zub31NSAFk0GLYfbw1wSM0UUljWsC3/view?usp=share_link'  ## Link copied from Google Drive
path = 'https://drive.google.com/uc?export=download&id='+ url.split('/')[-2]                   ## Split url and concatenate with 'https://drive.google.com/uc?export=download&id=' 
df = pd.read_csv(path, sep=',')#;df

# %%
df
# Out:
#      Unnamed: 0       Dates  Trmperature(degC)
# 0             0  1951-01-31               27.5
# 1             1  1951-02-28               30.2
# 2             2  1951-03-31               30.4
# 3             3  1951-04-30               25.8
# 4             4  1951-05-31               23.8
# ..          ...         ...                ...
# 655         655  2005-08-31               27.8
# 656         656  2005-09-30               28.2
# 657         657  2005-10-31               28.2
# 658         658  2005-11-30               25.4
# 659         659  2005-12-31               26.5
#
# [660 rows x 3 columns]

# %%
df['Dates']= pd.to_datetime(df['Dates'])

# %%
df = df.set_index('Dates')#;df

# %%
df
# Out:
#             Unnamed: 0  Trmperature(degC)
# Dates
# 1951-01-31           0               27.5
# 1951-02-28           1               30.2
# 1951-03-31           2               30.4
# 1951-04-30           3               25.8
# 1951-05-31           4               23.8
# ...                ...                ...
# 2005-08-31         655               27.8
# 2005-09-30         656               28.2
# 2005-10-31         657               28.2
# 2005-11-30         658               25.4
# 2005-12-31         659               26.5
#
# [660 rows x 2 columns]

# %%
## Select the months in March to May season using a condition

df_mam = df.iloc[((df.index.month >= 3) & (df.index.month <= 5))]#;df_mam
ann_mam.columns =['Dates','mam']#;ann_mam

# %%
ann_mam
# Out:
#        Dates        mam
# Dates
# 1951     3.0  26.666667
# 1952    15.0  27.133333
# 1953    27.0  26.166667
# 1954    39.0  28.266667
# 1955    51.0  27.533333
# 1956    63.0  26.633333
# 1957    75.0  26.133333
# 1958    87.0  27.433333
# 1959    99.0  25.733333
# 1960   111.0  26.266667
# 1961   123.0  27.233333
# 1962   135.0  28.700000
# 1963   147.0  26.333333
# 1964   159.0  28.333333
# 1965   171.0  26.100000
# 1966   183.0  26.900000
# 1967   195.0  24.933333
# 1968   207.0  26.100000
# 1969   219.0  27.900000
# 1970   231.0  26.633333
# 1971   243.0  26.833333
# 1972   255.0  27.100000
# 1973   267.0  28.266667
# 1974   279.0  27.433333
# 1975   291.0  26.000000
# 1976   303.0  24.233333
# 1977   315.0  27.600000
# 1978   327.0  25.733333
# 1979   339.0  26.633333
# 1980   351.0  27.633333
# 1981   363.0  26.900000
# 1982   375.0  28.100000
# 1983   387.0  28.466667
# 1984   399.0  26.366667
# 1985   411.0  28.433333
# 1986   423.0  25.466667
# 1987   435.0  24.933333
# 1988   447.0  25.933333
# 1989   459.0  24.233333
# 1990   471.0  28.200000
# 1991   483.0  27.500000
# 1992   495.0  27.466667
# 1993   507.0  27.266667
# 1994   519.0  28.300000
# 1995   531.0  26.800000
# 1996   543.0  27.633333
# 1997   555.0  27.933333
# 1998   567.0  27.100000
# 1999   579.0  26.833333
# 2000   591.0  26.166667
# 2001   603.0  28.366667
# 2002   615.0  25.800000
# 2003   627.0  29.533333
# 2004   639.0  25.533333
# 2005   651.0  28.433333

# %%
# Create figure and plot space
fig, ax = plt.subplots(figsize=(10, 10))

# Add x-axis and y-axis
ax.plot(ann_mam.index.values,
       ann_mam['mam'],
       color='purple')

# Set title and labels for axes
ax.set(xlabel="Years",
       ylabel="Temperature ($^o$C)",
       title="Average Temp for MAM Season")

# Rotate tick marks on x-axis
plt.setp(ax.get_xticklabels(), rotation=45)

plt.show()

# %%
ann_mam
# Out:
#        Unnamed: 0  Trmperature(degC)
# Dates
# 1951          3.0          26.666667
# 1952         15.0          27.133333
# 1953         27.0          26.166667
# 1954         39.0          28.266667
# 1955         51.0          27.533333
# 1956         63.0          26.633333
# 1957         75.0          26.133333
# 1958         87.0          27.433333
# 1959         99.0          25.733333
# 1960        111.0          26.266667
# 1961        123.0          27.233333
# 1962        135.0          28.700000
# 1963        147.0          26.333333
# 1964        159.0          28.333333
# 1965        171.0          26.100000
# 1966        183.0          26.900000
# 1967        195.0          24.933333
# 1968        207.0          26.100000
# 1969        219.0          27.900000
# 1970        231.0          26.633333
# 1971        243.0          26.833333
# 1972        255.0          27.100000
# 1973        267.0          28.266667
# 1974        279.0          27.433333
# 1975        291.0          26.000000
# 1976        303.0          24.233333
# 1977        315.0          27.600000
# 1978        327.0          25.733333
# 1979        339.0          26.633333
# 1980        351.0          27.633333
# 1981        363.0          26.900000
# 1982        375.0          28.100000
# 1983        387.0          28.466667
# 1984        399.0          26.366667
# 1985        411.0          28.433333
# 1986        423.0          25.466667
# 1987        435.0          24.933333
# 1988        447.0          25.933333
# 1989        459.0          24.233333
# 1990        471.0          28.200000
# 1991        483.0          27.500000
# 1992        495.0          27.466667
# 1993        507.0          27.266667
# 1994        519.0          28.300000
# 1995        531.0          26.800000
# 1996        543.0          27.633333
# 1997        555.0          27.933333
# 1998        567.0          27.100000
# 1999        579.0          26.833333
# 2000        591.0          26.166667
# 2001        603.0          28.366667
# 2002        615.0          25.800000
# 2003        627.0          29.533333
# 2004        639.0          25.533333
# 2005        651.0          28.433333

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(10, 10))
ax.plot(ann_mam.index.values,
       ann_mam['mam'],
       color='purple')
ax.set(xlabel="Years",
       ylabel="Precipitation (mm)",
       title="Total Rainfall for MAM Season")

# Rotate tick marks on x-axis
plt.setp(ax.get_xticklabels(), rotation=45)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'mam'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [35], line 4
#       1 import matplotlib.pyplot as plt
#       2 fig, ax = plt.subplots(figsize=(10, 10))
#       3 ax.plot(ann_mam.index.values,
# ----> 4        ann_mam['mam'],
#       5        color='purple')
#       6 ax.set(xlabel="Years",
#       7        ylabel="Precipitation (mm)",
#       8        title="Total Rainfall for MAM Season")
#      10 # Rotate tick marks on x-axis
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/pandas/core/indexes/base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 'mam'

# %%
import matplotlib.pyplot as plt

# %%
# Create figure and plot space
fig, ax = plt.subplots(figsize=(10, 10))

# Add x-axis and y-axis
ax.plot(ann_mam.index.values,
       ann_mam['mam'],
       color='purple')

# Set title and labels for axes
ax.set(xlabel="Years",
       ylabel="Precipitation (mm)",
       title="Total Rainfall for MAM Season")

# Rotate tick marks on x-axis
plt.setp(ax.get_xticklabels(), rotation=45)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'mam'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [12], line 6
#       2 fig, ax = plt.subplots(figsize=(10, 10))
#       4 # Add x-axis and y-axis
#       5 ax.plot(ann_mam.index.values,
# ----> 6        ann_mam['mam'],
#       7        color='purple')
#       9 # Set title and labels for axes
#      10 ax.set(xlabel="Years",
#      11        ylabel="Precipitation (mm)",
#      12        title="Total Rainfall for MAM Season")
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/pandas/core/indexes/base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 'mam'
